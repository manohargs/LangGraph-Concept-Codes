# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
#define state 
class BMIState(TypedDict):

    weight_kg: float
    height_m: float
    bmi: float
    category: str

# %%
def calculate_bmi(state:BMIState) -> BMIState:
    
    weight = state['weight_kg']
    height = state['height_m']

    bmi = weight/(height**2)

    state['bmi'] = round(bmi,2)

    return state

# %%
def label_bmi(state: BMIState) -> BMIState:

    bmi = state['bmi']

    if bmi < 18.5:
        state["category"] = "Underweight"
    elif 18.5 <= bmi < 25:
        state["category"] = "Normal"
    elif 25 <= bmi < 30:
        state["category"] = "Overweight"
    else:
        state["category"] = "Obese"

    return state

# %%
graph = StateGraph(BMIState)


workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\AI Codes\LangGraph\1_bmi_worflow.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/e%3A/AI%20Codes/LangGraph/1_bmi_worflow.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> graph = StateGraph(BMIState)
# ----> <a href='vscode-notebook-cell:/e%3A/AI%20Codes/LangGraph/1_bmi_worflow.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> workflow = graph.compile()
#
# File e:\AI Codes\LangGraph\venv\lib\site-packages\langgraph\graph\state.py:1088, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#    1085 interrupt_after = interrupt_after or []
#    1087 # validate the graph
# -> 1088 self.validate(
#    1089     interrupt=(
#    1090         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1091         if interrupt_after != "*"
#    1092         else []
#    1093     )
#    1094 )
#    1096 # prepare output channels
#    1097 output_channels = (
#    1098     "__root__"
#    1099     if len(self.schemas[self.output_schema]) == 1
#    (...)
#    1105     ]
#    1106 )
#
# File e:\AI Codes\LangGraph\venv\lib\site-packages\langgraph\graph\state.py:1000, in StateGraph.validate(self, interrupt)
#     997         raise ValueError(f"Found edge starting at unknown node '{source}'")
#     999 if START not in all_sources:
# -> 1000     raise ValueError(
#    1001         "Graph must have an entrypoint: add at least one edge from START to another node"
#    1002     )
#    1004 # assemble targets
#    1005 all_targets = {end for _, end in self._all_edges}
#
# ValueError: Graph must have an entrypoint: add at least one edge from START to another node

# %%
# execute the graph
intial_state = {'weight_kg':80, 'height_m':1.73}

final_state = workflow.invoke(intial_state)

print(final_state)

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())
