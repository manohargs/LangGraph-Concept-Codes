# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
model = ChatOpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# e:\AI Codes\LangGraph\2_simple_llm_workflow.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/AI%20Codes/LangGraph/2_simple_llm_workflow.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> model = ChatOpenAI()
#
# File e:\AI Codes\LangGraph\venv\lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File e:\AI Codes\LangGraph\venv\lib\site-packages\langchain_openai\chat_models\base.py:1021, in BaseChatOpenAI.validate_environment(self)
#    1011         self.http_async_client = httpx.AsyncClient(
#    1012             proxy=self.openai_proxy, verify=global_ssl_context
#    1013         )
#    1014     async_specific = {
#    1015         "http_client": self.http_async_client
#    1016         or _get_default_async_httpx_client(
#    (...)
#    1019         "api_key": async_api_key_value,
#    1020     }
# -> 1021     self.root_async_client = openai.AsyncOpenAI(
#    1022         **client_params,
#    1023         **async_specific,  # type: ignore[arg-type]
#    1024     )
#    1025     self.async_client = self.root_async_client.chat.completions
#    1026 return self
#
# File e:\AI Codes\LangGraph\venv\lib\site-packages\openai\_client.py:496, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     494     api_key = os.environ.get("OPENAI_API_KEY")
#     495 if api_key is None:
# --> 496     raise OpenAIError(
#     497         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     498     )
#     499 if callable(api_key):
#     500     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The average distance between the Moon and Earth is about 384,400 kilometers (238,855 miles).

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# 'The average distance from the Earth to the Moon is about 384,400 kilometers (238,855 miles).'
